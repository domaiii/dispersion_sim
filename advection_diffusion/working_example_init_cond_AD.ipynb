# %%
import numpy as np
from mpi4py import MPI
from basix.ufl import element
from dolfinx import mesh, fem, io, plot
from ufl import TrialFunction, TestFunction, dx

import pyvista
import ufl
from pathlib import Path
from dolfinx.fem.petsc import LinearProblem

from dolfinx import *

# %%
# Create mesh and define function space
y_lim = 3.0
x_lim = 3.0

domain = mesh.create_rectangle(MPI.COMM_WORLD, ((0,0),(x_lim, y_lim)), [128, 128])
V = fem.functionspace(domain, element("CG", domain.basix_cell(), 1))

# Parameters
theta = fem.Constant(domain, 1.0)
Pe = fem.Constant(domain, 1e1)
t_end = 10 
dt = 0.1

# %%
def initial_condition(x):
    r_sq = (x[0] - 0.3)**2 + (x[1] - 0.3)**2
    return np.where(r_sq < 0.2**2, 1.0, 0.0)

# Das Strömungsfeld `b` (hier `beta`) als Python-Funktion
def velocity_field(x):
    return np.vstack((-(x[1] - 0.5), (x[0] - 0.5)))

u0 = fem.Function(V)
u0.interpolate(initial_condition)

V_vec = fem.functionspace(domain, ("CG", 1, (domain.geometry.dim,)))
beta = fem.Function(V_vec)
beta.interpolate(velocity_field)

def boundary_all(x):
    return np.isclose(x[0], 0.0) | np.isclose(x[0], x_lim) | \
           np.isclose(x[1], 0.0) | np.isclose(x[1], y_lim)

u_D = fem.Constant(domain, 0.0)
bc = fem.dirichletbc(u_D, fem.locate_dofs_geometrical(V, boundary_all), V)

# %%
v = TestFunction(V)
u = TrialFunction(V)

# %%
h = ufl.CellDiameter(domain)
n = ufl.FacetNormal(domain)
nb = ufl.sqrt(ufl.inner(beta, beta))
tau = 0.5 * h * pow(4.0 / (Pe*h) + 2.0 * nb, -1.0)

# %%
A1 = (1.0 / Pe) * ufl.inner(ufl.grad(u), ufl.grad(v)) * dx + \
     ufl.inner(beta, ufl.grad(u)) * v * dx

A0 = (1.0 / Pe) * ufl.inner(ufl.grad(u0), ufl.grad(v)) * dx + \
     ufl.inner(beta, ufl.grad(u0)) * v * dx

A = (1/dt)*ufl.inner(u, v) * dx - (1/dt)* ufl.inner(u0,v) * dx + theta* A1 + (1-theta) * A0

F = A

# %%
problem = LinearProblem(ufl.lhs(F), ufl.rhs(F), bcs=[bc], petsc_options={"ksp_type": "gmres", "pc_type": "ilu"})
u = fem.Function(V)

xdmf = io.XDMFFile(domain.comm, "results.xdmf", "w")
xdmf.write_mesh(domain)

# %%
t = 0.0
u.x.array[:] = u0.x.array

while t < t_end:
    t += dt
    print(f"t = {t:.2f} von {t_end:.2f}")

    u = problem.solve()
    xdmf.write_function(u, t)
    u0.x.array[:] = u.x.array

xdmf.close()

domain.topology.create_entities(1)
domain.topology.create_connectivity(1, 2)
topology, cell_type, geometry = plot.vtk_mesh(domain, 1)
grid = pyvista.UnstructuredGrid(topology, cell_type, geometry)
grid.point_data["u"] = u.x.array.real
plotter = pyvista.Plotter()
plotter.add_mesh(grid, show_edges=True)
plotter.show()
# Out:
# t = 0.10 von 10.00
# t = 0.20 von 10.00
# t = 0.30 von 10.00
# t = 0.40 von 10.00
# t = 0.50 von 10.00
# t = 0.60 von 10.00
# t = 0.70 von 10.00
# t = 0.80 von 10.00
# t = 0.90 von 10.00
# t = 1.00 von 10.00
# t = 1.10 von 10.00
# t = 1.20 von 10.00
# t = 1.30 von 10.00
# t = 1.40 von 10.00
# t = 1.50 von 10.00
# t = 1.60 von 10.00
# t = 1.70 von 10.00
# t = 1.80 von 10.00
# t = 1.90 von 10.00
# t = 2.00 von 10.00
# t = 2.10 von 10.00
# t = 2.20 von 10.00
# t = 2.30 von 10.00
# t = 2.40 von 10.00
# t = 2.50 von 10.00
# t = 2.60 von 10.00
# t = 2.70 von 10.00
# t = 2.80 von 10.00
# t = 2.90 von 10.00
# t = 3.00 von 10.00
# t = 3.10 von 10.00
# t = 3.20 von 10.00
# t = 3.30 von 10.00
# t = 3.40 von 10.00
# t = 3.50 von 10.00
# t = 3.60 von 10.00
# t = 3.70 von 10.00
# t = 3.80 von 10.00
# t = 3.90 von 10.00
# t = 4.00 von 10.00
# t = 4.10 von 10.00
# t = 4.20 von 10.00
# t = 4.30 von 10.00
# t = 4.40 von 10.00
# t = 4.50 von 10.00
# t = 4.60 von 10.00
# t = 4.70 von 10.00
# t = 4.80 von 10.00
# t = 4.90 von 10.00
# t = 5.00 von 10.00
# t = 5.10 von 10.00
# t = 5.20 von 10.00
# t = 5.30 von 10.00
# t = 5.40 von 10.00
# t = 5.50 von 10.00
# t = 5.60 von 10.00
# t = 5.70 von 10.00
# t = 5.80 von 10.00
# t = 5.90 von 10.00
# t = 6.00 von 10.00
# t = 6.10 von 10.00
# t = 6.20 von 10.00
# t = 6.30 von 10.00
# t = 6.40 von 10.00
# t = 6.50 von 10.00
# t = 6.60 von 10.00
# t = 6.70 von 10.00
# t = 6.80 von 10.00
# t = 6.90 von 10.00
# t = 7.00 von 10.00
# t = 7.10 von 10.00
# t = 7.20 von 10.00
# t = 7.30 von 10.00
# t = 7.40 von 10.00
# t = 7.50 von 10.00
# t = 7.60 von 10.00
# t = 7.70 von 10.00
# t = 7.80 von 10.00
# t = 7.90 von 10.00
# t = 8.00 von 10.00
# t = 8.10 von 10.00
# t = 8.20 von 10.00
# t = 8.30 von 10.00
# t = 8.40 von 10.00
# t = 8.50 von 10.00
# t = 8.60 von 10.00
# t = 8.70 von 10.00
# t = 8.80 von 10.00
# t = 8.90 von 10.00
# t = 9.00 von 10.00
# t = 9.10 von 10.00
# t = 9.20 von 10.00
# t = 9.30 von 10.00
# t = 9.40 von 10.00
# t = 9.50 von 10.00
# t = 9.60 von 10.00
# t = 9.70 von 10.00
# t = 9.80 von 10.00
# t = 9.90 von 10.00
# t = 10.00 von 10.00
# t = 10.10 von 10.00
# <PIL.Image.Image image mode=RGB size=1024x768>
